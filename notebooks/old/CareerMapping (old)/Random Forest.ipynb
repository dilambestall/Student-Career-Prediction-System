# %%
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("/data/cleaned/processed_raw_CareerMapping_with_scores.csv")

# %%
X = df.drop(['Role', 'Role_encoded'], axis=1)

# %%
y = df['Role_encoded']

# %%
X
# Out:
#       Database Fundamentals  Computer Architecture  \
# 0                         6                      4
# 1                         6                      5
# 2                         6                      1
# 3                         6                      0
# 4                         6                      3
# ...                     ...                    ...
# 8523                      4                      4
# 8524                      4                      4
# 8525                      4                      4
# 8526                      4                      4
# 8527                      4                      4
#
#       Distributed Computing Systems  Cyber Security  Networking  \
# 0                                 4               4           4
# 1                                 4               4           4
# 2                                 4               4           4
# 3                                 4               4           4
# 4                                 4               4           4
# ...                             ...             ...         ...
# 8523                              4               4           4
# 8524                              4               4           4
# 8525                              4               4           4
# 8526                              4               4           4
# 8527                              4               4           4
#
#       Software Development  Programming Skills  Project Management  \
# 0                        4                   4                   4
# 1                        4                   4                   4
# 2                        4                   4                   4
# 3                        4                   4                   4
# 4                        4                   4                   4
# ...                    ...                 ...                 ...
# 8523                     4                   4                   4
# 8524                     4                   4                   4
# 8525                     4                   4                   4
# 8526                     4                   4                   4
# 8527                     4                   4                   4
#
#       Computer Forensics Fundamentals  Technical Communication  ...  \
# 0                                   4                        4  ...
# 1                                   4                        4  ...
# 2                                   4                        4  ...
# 3                                   4                        4  ...
# 4                                   4                        4  ...
# ...                               ...                      ...  ...
# 8523                                4                        4  ...
# 8524                                4                        4  ...
# 8525                                4                        4  ...
# 8526                                4                        4  ...
# 8527                                4                        4  ...
#
#       Extraversion  Agreeableness  Emotional_Range  Conversation  \
# 0         0.470877       0.039611         0.742567      0.086927
# 1         0.377581       0.090148         0.672546      0.071425
# 2         0.347739       0.138575         0.630705      0.095261
# 3         0.403756       0.114925         0.695280      0.122656
# 4         0.240337       0.050988         0.619390      0.065564
# ...            ...            ...              ...           ...
# 8523      0.464080       0.286505         0.646072      0.204770
# 8524      0.150246       0.091591         0.414744      0.046008
# 8525      0.359465       0.195782         0.625882      0.288711
# 8526      0.341132       0.098238         0.588750      0.050389
# 8527      0.494071       0.168254         0.607463      0.091884
#
#       Openness to Change  Hedonism  Self-enhancement  Self-transcendence  \
# 0               0.339776  0.091158          0.230518            0.208746
# 1               0.353678  0.104495          0.247432            0.196424
# 2               0.375125  0.135462          0.287253            0.268024
# 3               0.338899  0.161705          0.306562            0.258119
# 4               0.311896  0.147700          0.302978            0.207287
# ...                  ...       ...               ...                 ...
# 8523            0.395754  0.186430          0.277724            0.381149
# 8524            0.475964  0.247092          0.378122            0.302362
# 8525            0.655578  0.427479          0.510943            0.508034
# 8526            0.486217  0.154404          0.379121            0.288568
# 8527            0.429861  0.205960          0.344697            0.275756
#
#       tech_score  soft_skill_score
# 0       4.117647          0.340535
# 1       4.176471          0.318385
# 2       3.941176          0.355388
# 3       3.882353          0.353118
# 4       4.058824          0.304697
# ...          ...               ...
# 8523    4.235294          0.412711
# 8524    3.764706          0.308295
# 8525    3.647059          0.469372
# 8526    4.000000          0.359076
# 8527    3.882353          0.390559
#
# [8528 rows x 29 columns]

# %%
y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 8523    7
# 8524    7
# 8525    7
# 8526    7
# 8527    7
# Name: Role_encoded, Length: 8528, dtype: int64

# %%
scaler = MinMaxScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
X_scaled
# Out:
#       Database Fundamentals  Computer Architecture  \
# 0                  1.000000               0.666667
# 1                  1.000000               0.833333
# 2                  1.000000               0.166667
# 3                  1.000000               0.000000
# 4                  1.000000               0.500000
# ...                     ...                    ...
# 8523               0.666667               0.666667
# 8524               0.666667               0.666667
# 8525               0.666667               0.666667
# 8526               0.666667               0.666667
# 8527               0.666667               0.666667
#
#       Distributed Computing Systems  Cyber Security  Networking  \
# 0                          0.666667        0.666667    0.666667
# 1                          0.666667        0.666667    0.666667
# 2                          0.666667        0.666667    0.666667
# 3                          0.666667        0.666667    0.666667
# 4                          0.666667        0.666667    0.666667
# ...                             ...             ...         ...
# 8523                       0.666667        0.666667    0.666667
# 8524                       0.666667        0.666667    0.666667
# 8525                       0.666667        0.666667    0.666667
# 8526                       0.666667        0.666667    0.666667
# 8527                       0.666667        0.666667    0.666667
#
#       Software Development  Programming Skills  Project Management  \
# 0                 0.666667            0.666667            0.666667
# 1                 0.666667            0.666667            0.666667
# 2                 0.666667            0.666667            0.666667
# 3                 0.666667            0.666667            0.666667
# 4                 0.666667            0.666667            0.666667
# ...                    ...                 ...                 ...
# 8523              0.666667            0.666667            0.666667
# 8524              0.666667            0.666667            0.666667
# 8525              0.666667            0.666667            0.666667
# 8526              0.666667            0.666667            0.666667
# 8527              0.666667            0.666667            0.666667
#
#       Computer Forensics Fundamentals  Technical Communication  ...  \
# 0                            0.666667                 0.666667  ...
# 1                            0.666667                 0.666667  ...
# 2                            0.666667                 0.666667  ...
# 3                            0.666667                 0.666667  ...
# 4                            0.666667                 0.666667  ...
# ...                               ...                      ...  ...
# 8523                         0.666667                 0.666667  ...
# 8524                         0.666667                 0.666667  ...
# 8525                         0.666667                 0.666667  ...
# 8526                         0.666667                 0.666667  ...
# 8527                         0.666667                 0.666667  ...
#
#       Extraversion  Agreeableness  Emotional_Range  Conversation  \
# 0         0.573087       0.042014         0.705145      0.196931
# 1         0.428043       0.139067         0.564651      0.155921
# 2         0.381647       0.232067         0.480700      0.218979
# 3         0.468737       0.186649         0.610265      0.291455
# 4         0.214674       0.063863         0.457997      0.140414
# ...            ...            ...              ...           ...
# 8523      0.562520       0.516159         0.511534      0.508694
# 8524      0.074612       0.141839         0.047389      0.088679
# 8525      0.399878       0.341930         0.471023      0.730764
# 8526      0.371376       0.154604         0.396520      0.100267
# 8527      0.609147       0.289065         0.434066      0.210046
#
#       Openness to Change  Hedonism  Self-enhancement  Self-transcendence  \
# 0               0.379002  0.078080          0.281878            0.333071
# 1               0.406338  0.114640          0.315227            0.305612
# 2               0.448513  0.199526          0.393745            0.465167
# 3               0.377277  0.271463          0.431816            0.443094
# 4               0.324179  0.233073          0.424749            0.329821
# ...                  ...       ...               ...                 ...
# 8523            0.489078  0.339238          0.374954            0.717252
# 8524            0.646804  0.505524          0.572913            0.541683
# 8525            1.000000  1.000000          0.834800            1.000000
# 8526            0.666966  0.251451          0.574884            0.510945
# 8527            0.556147  0.392774          0.507009            0.482395
#
#       tech_score  soft_skill_score
# 0         0.8000          0.318561
# 1         0.8125          0.201408
# 2         0.7625          0.397125
# 3         0.7500          0.385117
# 4         0.7875          0.129011
# ...          ...               ...
# 8523      0.8250          0.700315
# 8524      0.7250          0.148039
# 8525      0.7000          1.000000
# 8526      0.7750          0.416631
# 8527      0.7500          0.583149
#
# [8528 rows x 29 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestClassifier(n_estimators=200, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
acc = accuracy_score(y_test, y_pred)

# %%
print(f"Random Forest's acc: {acc}")
# Out:
# Random Forest's acc: 1.0

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
row_sums = conf_matrix.sum(axis=1, keepdims=True)
conf_matrix_percent = conf_matrix / row_sums * 100
#print(conf_matrix_percent)

plt.figure(figsize=(15, 15))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)

for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j + 0.5, i + 0.5, f"{conf_matrix[i, j]}",
                 horizontalalignment="center",
                 verticalalignment="center", color="black", fontsize=10)
        plt.text(j + 0.5, i + 0.7, f"({conf_matrix_percent[i, j]:.2f}%)",
                 horizontalalignment="center",
                 verticalalignment="center", color="black", fontsize=10)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix for Test Set')
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       205
#            1       1.00      1.00      1.00        77
#            2       1.00      1.00      1.00       123
#            3       1.00      1.00      1.00       122
#            4       1.00      1.00      1.00        80
#            5       1.00      1.00      1.00        99
#            6       1.00      1.00      1.00       113
#            7       1.00      1.00      1.00       100
#            8       1.00      1.00      1.00        91
#            9       1.00      1.00      1.00        82
#           10       1.00      1.00      1.00        94
#           11       1.00      1.00      1.00        95
#           12       1.00      1.00      1.00       110
#           13       1.00      1.00      1.00       116
#           14       1.00      1.00      1.00       105
#           15       1.00      1.00      1.00        94
#
#     accuracy                           1.00      1706
#    macro avg       1.00      1.00      1.00      1706
# weighted avg       1.00      1.00      1.00      1706

# %%
feature_imp = pd.Series(rf_model.feature_importances_, index=X.columns).sort_values(ascending=False)

# %%
print("\n--- Top 5 Yếu tố quan trọng nhất ---")
print(feature_imp.head(5))
# Out:
# --- Top 5 Yếu tố quan trọng nhất ---
# Networking                       0.063161
# Distributed Computing Systems    0.059968
# Software Development             0.059592
# Project Management               0.059189
# Business Analysis                0.056563
# dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_imp.head(10), y=feature_imp.head(10).index)
plt.title("Top 10 Yếu tố ảnh hưởng đến Gợi ý nghề nghiệp")
plt.xlabel("Mức độ quan trọng")
plt.show()

# %%
joblib.dump(rf_model, '../../../src/career_prediction_model.pkl')
# Out:
# ['../../src/career_prediction_model.pkl']

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df = pd.read_csv("/data/cleaned/processed_raw_CareerMapping.csv")

# %%
X = df.drop(['Role', 'Role_encoded'], axis=1)

# %%
y = df['Role_encoded']

# %%
X
# Out:
#       Computer Architecture  Programming Skills  Project Management  \
# 0                  4.000000            4.000000            4.000000
# 1                  5.000000            4.000000            4.000000
# 2                  1.000000            4.000000            4.000000
# 3                  0.000000            4.000000            4.000000
# 4                  3.000000            4.000000            4.000000
# ...                     ...                 ...                 ...
# 4111               0.636043            0.137336            0.226302
# 4112               0.192270            0.135045            0.644441
# 4113               0.554620            0.724794            0.255892
# 4114               0.465681            0.103231            0.229899
# 4115               0.588068            0.537394            0.166209
#
#       Communication skills  Openness  Conscientousness  Extraversion  \
# 0                 4.000000  0.714603          0.480564      0.470877
# 1                 4.000000  0.617218          0.452903      0.377581
# 2                 4.000000  0.814072          0.461668      0.347739
# 3                 4.000000  0.607495          0.521783      0.403756
# 4                 4.000000  0.781293          0.319539      0.240337
# ...                    ...       ...               ...           ...
# 4111              0.056456  0.704709          0.480178      0.558140
# 4112              0.782071  0.879181          0.726732      0.715623
# 4113              0.122183  0.159705          0.963999      0.414078
# 4114              0.595242  0.621454          0.010347      0.574015
# 4115              0.510045  0.009768          0.316166      0.658930
#
#       Agreeableness  Emotional_Range  Conversation  Openness to Change  \
# 0          0.039611         0.742567      0.086927            0.339776
# 1          0.090148         0.672546      0.071425            0.353678
# 2          0.138575         0.630705      0.095261            0.375125
# 3          0.114925         0.695280      0.122656            0.338899
# 4          0.050988         0.619390      0.065564            0.311896
# ...             ...              ...           ...                 ...
# 4111       0.238608         0.800011      0.780420            0.889618
# 4112       0.976057         0.972935      0.027870            0.402814
# 4113       0.097954         0.402532      0.959647            0.816209
# 4114       0.435590         0.852310      0.640508            0.716231
# 4115       0.398523         0.989874      0.977358            0.739749
#
#       Hedonism  Self-enhancement  Self-transcendence
# 0     0.091158          0.230518            0.208746
# 1     0.104495          0.247432            0.196424
# 2     0.135462          0.287253            0.268024
# 3     0.161705          0.306562            0.258119
# 4     0.147700          0.302978            0.207287
# ...        ...               ...                 ...
# 4111  0.230480          0.655361            0.149937
# 4112  0.862264          0.628395            0.586368
# 4113  0.398565          0.441053            0.072179
# 4114  0.458104          0.368780            0.516576
# 4115  0.153998          0.484608            0.499577
#
# [4116 rows x 14 columns]

# %%
y
# Out:
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6
#         ..
# 4111    12
# 4112     7
# 4113    13
# 4114     8
# 4115     9
# Name: Role_encoded, Length: 4116, dtype: int64

# %%
scaler = MinMaxScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
X_scaled
# Out:
#       Computer Architecture  Programming Skills  Project Management  \
# 0                  0.666667            0.666667            0.666667
# 1                  0.833333            0.666667            0.666667
# 2                  0.166667            0.666667            0.666667
# 3                  0.000000            0.666667            0.666667
# 4                  0.500000            0.666667            0.666667
# ...                     ...                 ...                 ...
# 4111               0.106007            0.022889            0.037717
# 4112               0.032045            0.022508            0.107407
# 4113               0.092437            0.120799            0.042649
# 4114               0.077613            0.017205            0.038317
# 4115               0.098011            0.089566            0.027702
#
#       Communication skills  Openness  Conscientousness  Extraversion  \
# 0                 0.666667  0.716175          0.480310      0.470353
# 1                 0.666667  0.618465          0.452624      0.376950
# 2                 0.666667  0.815976          0.461397      0.347072
# 3                 0.666667  0.608710          0.521567      0.403155
# 4                 0.666667  0.783087          0.319139      0.239546
# ...                    ...       ...               ...           ...
# 4111              0.009409  0.706248          0.479924      0.557717
# 4112              0.130345  0.881302          0.726702      0.715383
# 4113              0.020364  0.159426          0.964184      0.413489
# 4114              0.099207  0.622716          0.009667      0.573611
# 4115              0.085007  0.008989          0.315763      0.658624
#
#       Agreeableness  Emotional_Range  Conversation  Openness to Change  \
# 0          0.039195         0.743468      0.085414            0.339526
# 1          0.089797         0.673265      0.069821            0.353436
# 2          0.138287         0.631317      0.093798            0.374896
# 3          0.114607         0.696058      0.121356            0.338648
# 4          0.050586         0.619972      0.063925            0.311630
# ...             ...              ...           ...                 ...
# 4111       0.238450         0.801059      0.783033            0.889697
# 4112       0.976858         0.974430      0.026006            0.402602
# 4113       0.097614         0.402555      0.963327            0.816244
# 4114       0.435689         0.853493      0.642289            0.716207
# 4115       0.398574         0.991412      0.981143            0.739738
#
#       Hedonism  Self-enhancement  Self-transcendence
# 0     0.089076          0.230310            0.208745
# 1     0.102451          0.247233            0.196407
# 2     0.133504          0.287078            0.268101
# 3     0.159821          0.306398            0.258183
# 4     0.145777          0.302811            0.207285
# ...        ...               ...                 ...
# 4111  0.228789          0.655399            0.149860
# 4112  0.862344          0.628417            0.586858
# 4113  0.397345          0.440967            0.072001
# 4114  0.457051          0.368651            0.516976
# 4115  0.152092          0.484546            0.499954
#
# [4116 rows x 14 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestClassifier(n_estimators=200, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
acc = accuracy_score(y_test, y_pred)

# %%
print(f"Random Forest's acc: {acc}")
# Out:
# Random Forest's acc: 0.7839805825242718

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        68
#            1       0.61      0.59      0.60        39
#            2       0.83      0.80      0.82        81
#            3       0.80      0.82      0.81        65
#            4       0.75      0.60      0.67        25
#            5       0.83      0.75      0.79        40
#            6       0.75      0.77      0.76        57
#            7       0.69      0.76      0.72        45
#            8       0.91      0.66      0.77        47
#            9       0.79      0.76      0.78        41
#           10       0.61      0.79      0.69        34
#           11       0.72      0.83      0.77        58
#           12       0.88      0.86      0.87        50
#           13       0.88      0.86      0.87        87
#           14       0.82      0.75      0.78        48
#           15       0.67      0.82      0.74        39
#
#     accuracy                           0.78       824
#    macro avg       0.78      0.77      0.77       824
# weighted avg       0.79      0.78      0.78       824

# %%
feature_imp = pd.Series(rf_model.feature_importances_, index=X.columns).sort_values(ascending=False)

# %%
print("\n--- Top 5 Yếu tố quan trọng nhất ---")
print(feature_imp.head(5))
# Out:
# --- Top 5 Yếu tố quan trọng nhất ---
# Self-transcendence    0.093148
# Conversation          0.090160
# Extraversion          0.083702
# Agreeableness         0.082910
# Openness              0.081574
# dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_imp.head(10), y=feature_imp.head(10).index)
plt.title("Top 10 Yếu tố ảnh hưởng đến Gợi ý nghề nghiệp")
plt.xlabel("Mức độ quan trọng")
plt.show()
