# %%
import pandas as pd
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
df = pd.read_csv("/data/cleaned/processed_raw_CareerMapping_with_scores.csv")

# %%
X = df.drop(['Role', 'Role_encoded'], axis=1)

# %%
y = df['Role']

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
X
# Out:
#       Database Fundamentals  Computer Architecture  \
# 0                         6                      4
# 1                         6                      5
# 2                         6                      1
# 3                         6                      0
# 4                         6                      3
# ...                     ...                    ...
# 8523                      4                      4
# 8524                      4                      4
# 8525                      4                      4
# 8526                      4                      4
# 8527                      4                      4
#
#       Distributed Computing Systems  Cyber Security  Networking  \
# 0                                 4               4           4
# 1                                 4               4           4
# 2                                 4               4           4
# 3                                 4               4           4
# 4                                 4               4           4
# ...                             ...             ...         ...
# 8523                              4               4           4
# 8524                              4               4           4
# 8525                              4               4           4
# 8526                              4               4           4
# 8527                              4               4           4
#
#       Software Development  Programming Skills  Project Management  \
# 0                        4                   4                   4
# 1                        4                   4                   4
# 2                        4                   4                   4
# 3                        4                   4                   4
# 4                        4                   4                   4
# ...                    ...                 ...                 ...
# 8523                     4                   4                   4
# 8524                     4                   4                   4
# 8525                     4                   4                   4
# 8526                     4                   4                   4
# 8527                     4                   4                   4
#
#       Computer Forensics Fundamentals  Technical Communication  ...  \
# 0                                   4                        4  ...
# 1                                   4                        4  ...
# 2                                   4                        4  ...
# 3                                   4                        4  ...
# 4                                   4                        4  ...
# ...                               ...                      ...  ...
# 8523                                4                        4  ...
# 8524                                4                        4  ...
# 8525                                4                        4  ...
# 8526                                4                        4  ...
# 8527                                4                        4  ...
#
#       Extraversion  Agreeableness  Emotional_Range  Conversation  \
# 0         0.470877       0.039611         0.742567      0.086927
# 1         0.377581       0.090148         0.672546      0.071425
# 2         0.347739       0.138575         0.630705      0.095261
# 3         0.403756       0.114925         0.695280      0.122656
# 4         0.240337       0.050988         0.619390      0.065564
# ...            ...            ...              ...           ...
# 8523      0.464080       0.286505         0.646072      0.204770
# 8524      0.150246       0.091591         0.414744      0.046008
# 8525      0.359465       0.195782         0.625882      0.288711
# 8526      0.341132       0.098238         0.588750      0.050389
# 8527      0.494071       0.168254         0.607463      0.091884
#
#       Openness to Change  Hedonism  Self-enhancement  Self-transcendence  \
# 0               0.339776  0.091158          0.230518            0.208746
# 1               0.353678  0.104495          0.247432            0.196424
# 2               0.375125  0.135462          0.287253            0.268024
# 3               0.338899  0.161705          0.306562            0.258119
# 4               0.311896  0.147700          0.302978            0.207287
# ...                  ...       ...               ...                 ...
# 8523            0.395754  0.186430          0.277724            0.381149
# 8524            0.475964  0.247092          0.378122            0.302362
# 8525            0.655578  0.427479          0.510943            0.508034
# 8526            0.486217  0.154404          0.379121            0.288568
# 8527            0.429861  0.205960          0.344697            0.275756
#
#       tech_score  soft_skill_score
# 0       4.117647          0.340535
# 1       4.176471          0.318385
# 2       3.941176          0.355388
# 3       3.882353          0.353118
# 4       4.058824          0.304697
# ...          ...               ...
# 8523    4.235294          0.412711
# 8524    3.764706          0.308295
# 8525    3.647059          0.469372
# 8526    4.000000          0.359076
# 8527    3.882353          0.390559
#
# [8528 rows x 29 columns]

# %%
y_encoded
# Out:
# array([6, 6, 6, ..., 7, 7, 7], shape=(8528,))

# %%
scaler = MinMaxScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
X_scaled
# Out:
#       Database Fundamentals  Computer Architecture  \
# 0                  1.000000               0.666667
# 1                  1.000000               0.833333
# 2                  1.000000               0.166667
# 3                  1.000000               0.000000
# 4                  1.000000               0.500000
# ...                     ...                    ...
# 8523               0.666667               0.666667
# 8524               0.666667               0.666667
# 8525               0.666667               0.666667
# 8526               0.666667               0.666667
# 8527               0.666667               0.666667
#
#       Distributed Computing Systems  Cyber Security  Networking  \
# 0                          0.666667        0.666667    0.666667
# 1                          0.666667        0.666667    0.666667
# 2                          0.666667        0.666667    0.666667
# 3                          0.666667        0.666667    0.666667
# 4                          0.666667        0.666667    0.666667
# ...                             ...             ...         ...
# 8523                       0.666667        0.666667    0.666667
# 8524                       0.666667        0.666667    0.666667
# 8525                       0.666667        0.666667    0.666667
# 8526                       0.666667        0.666667    0.666667
# 8527                       0.666667        0.666667    0.666667
#
#       Software Development  Programming Skills  Project Management  \
# 0                 0.666667            0.666667            0.666667
# 1                 0.666667            0.666667            0.666667
# 2                 0.666667            0.666667            0.666667
# 3                 0.666667            0.666667            0.666667
# 4                 0.666667            0.666667            0.666667
# ...                    ...                 ...                 ...
# 8523              0.666667            0.666667            0.666667
# 8524              0.666667            0.666667            0.666667
# 8525              0.666667            0.666667            0.666667
# 8526              0.666667            0.666667            0.666667
# 8527              0.666667            0.666667            0.666667
#
#       Computer Forensics Fundamentals  Technical Communication  ...  \
# 0                            0.666667                 0.666667  ...
# 1                            0.666667                 0.666667  ...
# 2                            0.666667                 0.666667  ...
# 3                            0.666667                 0.666667  ...
# 4                            0.666667                 0.666667  ...
# ...                               ...                      ...  ...
# 8523                         0.666667                 0.666667  ...
# 8524                         0.666667                 0.666667  ...
# 8525                         0.666667                 0.666667  ...
# 8526                         0.666667                 0.666667  ...
# 8527                         0.666667                 0.666667  ...
#
#       Extraversion  Agreeableness  Emotional_Range  Conversation  \
# 0         0.573087       0.042014         0.705145      0.196931
# 1         0.428043       0.139067         0.564651      0.155921
# 2         0.381647       0.232067         0.480700      0.218979
# 3         0.468737       0.186649         0.610265      0.291455
# 4         0.214674       0.063863         0.457997      0.140414
# ...            ...            ...              ...           ...
# 8523      0.562520       0.516159         0.511534      0.508694
# 8524      0.074612       0.141839         0.047389      0.088679
# 8525      0.399878       0.341930         0.471023      0.730764
# 8526      0.371376       0.154604         0.396520      0.100267
# 8527      0.609147       0.289065         0.434066      0.210046
#
#       Openness to Change  Hedonism  Self-enhancement  Self-transcendence  \
# 0               0.379002  0.078080          0.281878            0.333071
# 1               0.406338  0.114640          0.315227            0.305612
# 2               0.448513  0.199526          0.393745            0.465167
# 3               0.377277  0.271463          0.431816            0.443094
# 4               0.324179  0.233073          0.424749            0.329821
# ...                  ...       ...               ...                 ...
# 8523            0.489078  0.339238          0.374954            0.717252
# 8524            0.646804  0.505524          0.572913            0.541683
# 8525            1.000000  1.000000          0.834800            1.000000
# 8526            0.666966  0.251451          0.574884            0.510945
# 8527            0.556147  0.392774          0.507009            0.482395
#
#       tech_score  soft_skill_score
# 0         0.8000          0.318561
# 1         0.8125          0.201408
# 2         0.7625          0.397125
# 3         0.7500          0.385117
# 4         0.7875          0.129011
# ...          ...               ...
# 8523      0.8250          0.700315
# 8524      0.7250          0.148039
# 8525      0.7000          1.000000
# 8526      0.7750          0.416631
# 8527      0.7500          0.583149
#
# [8528 rows x 29 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.3, random_state=42)

# %%
xgb_model = xgb.XGBClassifier(
    objective='multi:softmax',
    num_class=len(le.classes_),
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    random_state=42
)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_class=16, ...)

# %%
y_pred = xgb_model.predict(X_test)
y_pred_label = le.inverse_transform(y_pred)
y_test_label = le.inverse_transform(y_test)

# %%
print("Accuracy của XGBoost:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy của XGBoost: 1.0

# %% [markdown]
# ------------------------------------------------------------------------------------------

# %%
df = pd.read_csv("/data/cleaned/processed_raw_CareerMapping.csv")

# %%
X = df.drop(['Role', 'Role_encoded'], axis=1)

# %%
y = df['Role']

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
X
# Out:
#       Database Fundamentals  Computer Architecture  \
# 0                         6                      4
# 1                         6                      5
# 2                         6                      1
# 3                         6                      0
# 4                         6                      3
# ...                     ...                    ...
# 8523                      4                      4
# 8524                      4                      4
# 8525                      4                      4
# 8526                      4                      4
# 8527                      4                      4
#
#       Distributed Computing Systems  Cyber Security  Networking  \
# 0                                 4               4           4
# 1                                 4               4           4
# 2                                 4               4           4
# 3                                 4               4           4
# 4                                 4               4           4
# ...                             ...             ...         ...
# 8523                              4               4           4
# 8524                              4               4           4
# 8525                              4               4           4
# 8526                              4               4           4
# 8527                              4               4           4
#
#       Software Development  Programming Skills  Project Management  \
# 0                        4                   4                   4
# 1                        4                   4                   4
# 2                        4                   4                   4
# 3                        4                   4                   4
# 4                        4                   4                   4
# ...                    ...                 ...                 ...
# 8523                     4                   4                   4
# 8524                     4                   4                   4
# 8525                     4                   4                   4
# 8526                     4                   4                   4
# 8527                     4                   4                   4
#
#       Computer Forensics Fundamentals  Technical Communication  ...  Openness  \
# 0                                   4                        4  ...  0.714603
# 1                                   4                        4  ...  0.617218
# 2                                   4                        4  ...  0.814072
# 3                                   4                        4  ...  0.607495
# 4                                   4                        4  ...  0.781293
# ...                               ...                      ...  ...       ...
# 8523                                4                        4  ...  0.712385
# 8524                                4                        4  ...  0.868257
# 8525                                4                        4  ...  0.692413
# 8526                                4                        4  ...  0.818076
# 8527                                4                        4  ...  0.802944
#
#       Conscientousness  Extraversion  Agreeableness  Emotional_Range  \
# 0             0.480564      0.470877       0.039611         0.742567
# 1             0.452903      0.377581       0.090148         0.672546
# 2             0.461668      0.347739       0.138575         0.630705
# 3             0.521783      0.403756       0.114925         0.695280
# 4             0.319539      0.240337       0.050988         0.619390
# ...                ...           ...            ...              ...
# 8523          0.572244      0.464080       0.286505         0.646072
# 8524          0.108561      0.150246       0.091591         0.414744
# 8525          0.429431      0.359465       0.195782         0.625882
# 8526          0.385867      0.341132       0.098238         0.588750
# 8527          0.484702      0.494071       0.168254         0.607463
#
#       Conversation  Openness to Change  Hedonism  Self-enhancement  \
# 0         0.086927            0.339776  0.091158          0.230518
# 1         0.071425            0.353678  0.104495          0.247432
# 2         0.095261            0.375125  0.135462          0.287253
# 3         0.122656            0.338899  0.161705          0.306562
# 4         0.065564            0.311896  0.147700          0.302978
# ...            ...                 ...       ...               ...
# 8523      0.204770            0.395754  0.186430          0.277724
# 8524      0.046008            0.475964  0.247092          0.378122
# 8525      0.288711            0.655578  0.427479          0.510943
# 8526      0.050389            0.486217  0.154404          0.379121
# 8527      0.091884            0.429861  0.205960          0.344697
#
#       Self-transcendence
# 0               0.208746
# 1               0.196424
# 2               0.268024
# 3               0.258119
# 4               0.207287
# ...                  ...
# 8523            0.381149
# 8524            0.302362
# 8525            0.508034
# 8526            0.288568
# 8527            0.275756
#
# [8528 rows x 27 columns]

# %%
y_encoded
# Out:
# array([6, 6, 6, ..., 7, 7, 7], shape=(8528,))

# %%
scaler = MinMaxScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
X_scaled
# Out:
#       Database Fundamentals  Computer Architecture  \
# 0                  1.000000               0.666667
# 1                  1.000000               0.833333
# 2                  1.000000               0.166667
# 3                  1.000000               0.000000
# 4                  1.000000               0.500000
# ...                     ...                    ...
# 8523               0.666667               0.666667
# 8524               0.666667               0.666667
# 8525               0.666667               0.666667
# 8526               0.666667               0.666667
# 8527               0.666667               0.666667
#
#       Distributed Computing Systems  Cyber Security  Networking  \
# 0                          0.666667        0.666667    0.666667
# 1                          0.666667        0.666667    0.666667
# 2                          0.666667        0.666667    0.666667
# 3                          0.666667        0.666667    0.666667
# 4                          0.666667        0.666667    0.666667
# ...                             ...             ...         ...
# 8523                       0.666667        0.666667    0.666667
# 8524                       0.666667        0.666667    0.666667
# 8525                       0.666667        0.666667    0.666667
# 8526                       0.666667        0.666667    0.666667
# 8527                       0.666667        0.666667    0.666667
#
#       Software Development  Programming Skills  Project Management  \
# 0                 0.666667            0.666667            0.666667
# 1                 0.666667            0.666667            0.666667
# 2                 0.666667            0.666667            0.666667
# 3                 0.666667            0.666667            0.666667
# 4                 0.666667            0.666667            0.666667
# ...                    ...                 ...                 ...
# 8523              0.666667            0.666667            0.666667
# 8524              0.666667            0.666667            0.666667
# 8525              0.666667            0.666667            0.666667
# 8526              0.666667            0.666667            0.666667
# 8527              0.666667            0.666667            0.666667
#
#       Computer Forensics Fundamentals  Technical Communication  ...  Openness  \
# 0                            0.666667                 0.666667  ...  0.447745
# 1                            0.666667                 0.666667  ...  0.158897
# 2                            0.666667                 0.666667  ...  0.742773
# 3                            0.666667                 0.666667  ...  0.130058
# 4                            0.666667                 0.666667  ...  0.645548
# ...                               ...                      ...  ...       ...
# 8523                         0.666667                 0.666667  ...  0.441166
# 8524                         0.666667                 0.666667  ...  0.903486
# 8525                         0.666667                 0.666667  ...  0.381928
# 8526                         0.666667                 0.666667  ...  0.754650
# 8527                         0.666667                 0.666667  ...  0.709766
#
#       Conscientousness  Extraversion  Agreeableness  Emotional_Range  \
# 0             0.594344      0.573087       0.042014         0.705145
# 1             0.550150      0.428043       0.139067         0.564651
# 2             0.564154      0.381647       0.232067         0.480700
# 3             0.660199      0.468737       0.186649         0.610265
# 4             0.337077      0.214674       0.063863         0.457997
# ...                ...           ...            ...              ...
# 8523          0.740821      0.562520       0.516159         0.511534
# 8524          0.000000      0.074612       0.141839         0.047389
# 8525          0.512650      0.399878       0.341930         0.471023
# 8526          0.443048      0.371376       0.154604         0.396520
# 8527          0.600956      0.609147       0.289065         0.434066
#
#       Conversation  Openness to Change  Hedonism  Self-enhancement  \
# 0         0.196931            0.379002  0.078080          0.281878
# 1         0.155921            0.406338  0.114640          0.315227
# 2         0.218979            0.448513  0.199526          0.393745
# 3         0.291455            0.377277  0.271463          0.431816
# 4         0.140414            0.324179  0.233073          0.424749
# ...            ...                 ...       ...               ...
# 8523      0.508694            0.489078  0.339238          0.374954
# 8524      0.088679            0.646804  0.505524          0.572913
# 8525      0.730764            1.000000  1.000000          0.834800
# 8526      0.100267            0.666966  0.251451          0.574884
# 8527      0.210046            0.556147  0.392774          0.507009
#
#       Self-transcendence
# 0               0.333071
# 1               0.305612
# 2               0.465167
# 3               0.443094
# 4               0.329821
# ...                  ...
# 8523            0.717252
# 8524            0.541683
# 8525            1.000000
# 8526            0.510945
# 8527            0.482395
#
# [8528 rows x 27 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.3, random_state=42)

# %%
xgb_model = xgb.XGBClassifier(
    objective='multi:softmax',
    num_class=len(le.classes_),
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    random_state=42
)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_class=16, ...)

# %%
y_pred = xgb_model.predict(X_test)
y_pred_label = le.inverse_transform(y_pred)
y_test_label = le.inverse_transform(y_test)

# %%
print("Accuracy của XGBoost:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy của XGBoost: 1.0
